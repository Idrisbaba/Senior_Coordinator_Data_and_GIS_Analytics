# %%
# Before starting the analysis its very important to import the necessary libary that will allow to carry out my analyses
#I will print the version used

import sys
import geopandas as gpd
import pandas as pd
import shapely
import duckdb
import pysal
from datetime import datetime, time

print("Python:", sys.version)
print("GeoPandas:", gpd.__version__)
print("Pandas:", pd.__version__)
print("Shapely:", shapely.__version__)
print("DuckDB:", duckdb.__version__)
print("PySAL:", pysal.__version__)
# Out:
# Python: 3.11.10 | packaged by conda-forge | (main, Sep 30 2024, 17:50:51) [MSC v.1941 64 bit (AMD64)]
# GeoPandas: 1.0.1
# Pandas: 2.2.3
# Shapely: 2.1.1
# DuckDB: 1.1.1
# PySAL: 24.7
